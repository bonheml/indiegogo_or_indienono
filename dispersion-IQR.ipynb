# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
indiegogo = pd.read_csv('indiegogo_cleaned_dataset.tsv', sep='\t')

# %%
indiegogo['is_funded'] = indiegogo.collected_percentage.apply(lambda x: True if x >= 100 else False)

# %%
with sns.plotting_context("notebook", font_scale=1.5):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(y="title_len", x="is_funded", data=indiegogo, palette="viridis")

# %%
indiegogo.groupby('category_slug').count().sort_values('title_len', ascending=False)
# Out:
#                     title_len  tagline_len  pledges_count  currency_code  \
# category_slug
# creative_works          87174        87174          87174          87174
# community_projects      37757        37757          37757          37757
# tech_innovation         14120        14120          14120          14120
#
#                     collected_percentage  has_partner  target_amount  \
# category_slug
# creative_works                     87174        87174          87174
# community_projects                 37757        37757          37757
# tech_innovation                    14120        14120          14120
#
#                     is_funded
# category_slug
# creative_works          87174
# community_projects      37757
# tech_innovation         14120

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="collected_percentage", hue="has_partner", data=indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="target_amount", data=indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="title_len", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="tagline_len", data=indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="has_partner", y="collected_percentage", data=indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="has_partner", y="target_amount", data=indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=1.5):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(y="pledges_count", x="category_slug", data=indiegogo, palette="viridis")
