# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
indiegogo = pd.read_csv('indiegogo_cleaned_dataset.tsv', sep='\t')

# %%
indiegogo['is_funded'] = indiegogo.collected_percentage.apply(lambda x: True if x >= 100 else False)

# %%
with sns.plotting_context("notebook", font_scale=1.5):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(y="title_len", x="is_funded", data=indiegogo, palette="viridis")

# %%
indiegogo.groupby('category_slug').count().sort_values('title_len', ascending=False)
# Out:
#                     title_len  tagline_len  pledges_count  balance  \
# category_slug
# film                    44787        44787          44787    44787
# local_businesses        18418        18418          18418    18418
# music                   17429        17429          17429    17429
# education               15821        15821          15821    15821
# dance                   11393        11393          11393    11393
# art                      7273         7273           7273     7273
# health                   7157         7157           7157     7157
# writing                  5073         5073           5073     5073
# fashion                  3245         3245           3245     3245
# animals                  2988         2988           2988     2988
# environment              2630         2630           2630     2630
# phones_accessories       2257         2257           2257     2257
# games                    2059         2059           2059     2059
# comics                   1029         1029           1029     1029
# travel_outdoors           968          968            968      968
# home                      820          820            820      820
# photography               656          656            656      656
# productivity              425          425            425      425
# human_rights              366          366            366      366
# transportation            357          357            357      357
# technology                226          226            226      226
# audio                     209          209            209      209
# camera_gear               205          205            205      205
# food                      142          142            142      142
# community                  97           97             97       97
# wellness                   70           70             70       70
# series                     63           63             63       63
# creative_works             60           60             60       60
# culture                    36           36             36       36
# spirituality               15           15             15       15
# design                     13           13             13       13
# small_business             12           12             12       12
# podcast                     6            6              6        6
# video_web                   5            5              5        5
# politics                    3            3              3        3
# religion                    2            2              2        2
# sports                      1            1              1        1
# theatre                     1            1              1        1
# transmedia                  1            1              1        1
#
#                     collected_percentage  has_partner  is_funded
# category_slug
# film                               44787        44787      44787
# local_businesses                   18418        18418      18418
# music                              17429        17429      17429
# education                          15821        15821      15821
# dance                              11393        11393      11393
# art                                 7273         7273       7273
# health                              7157         7157       7157
# writing                             5073         5073       5073
# fashion                             3245         3245       3245
# animals                             2988         2988       2988
# environment                         2630         2630       2630
# phones_accessories                  2257         2257       2257
# games                               2059         2059       2059
# comics                              1029         1029       1029
# travel_outdoors                      968          968        968
# home                                 820          820        820
# photography                          656          656        656
# productivity                         425          425        425
# human_rights                         366          366        366
# transportation                       357          357        357
# technology                           226          226        226
# audio                                209          209        209
# camera_gear                          205          205        205
# food                                 142          142        142
# community                             97           97         97
# wellness                              70           70         70
# series                                63           63         63
# creative_works                        60           60         60
# culture                               36           36         36
# spirituality                          15           15         15
# design                                13           13         13
# small_business                        12           12         12
# podcast                                6            6          6
# video_web                              5            5          5
# politics                               3            3          3
# religion                               2            2          2
# sports                                 1            1          1
# theatre                                1            1          1
# transmedia                             1            1          1

# %%
popular_indiegogo = indiegogo[indiegogo.category_slug.isin(['film', 'local_businesses', 'music'])]

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="collected_percentage", hue="has_partner", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="balance", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="title_len", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="category_slug", y="tagline_len", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="has_partner", y="collected_percentage", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=2):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(x="has_partner", y="balance", data=popular_indiegogo)

# %%
with sns.plotting_context("notebook", font_scale=1.5):
    plt.figure(figsize=(20, 20))
    ax = sns.boxplot(y="pledges_count", x="category_slug", data=popular_indiegogo, palette="viridis")
